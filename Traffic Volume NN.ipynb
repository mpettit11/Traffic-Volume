# %%
import numpy as np
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split

Traffic_Data = pd.read_csv('/Users/MattPettit/Desktop/Metro_Interstate_Traffic_Volume.csv')
Traffic_DF = pd.DataFrame(Traffic_Data)
Traffic_DF = Traffic_DF.drop(columns=['date_time'])
Traffic_DF_X = Traffic_DF.iloc[:,0:5]
Traffic_DF_Y = Traffic_DF.iloc[:,5]

traff_scale = scale(Traffic_DF_X)
traff_scale_DF = pd.DataFrame(traff_scale)

#Train_test_split
x = traff_scale_DF
y = Traffic_DF_Y
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=.7)
n_cols = x_train.shape[1]

#Model build
traff_model = Sequential()
traff_model.add(Dense(100, activation='relu', input_shape=(n_cols,)))
traff_model.add(Dense(100, activation='relu'))
traff_model.add(Dense(100, activation='relu'))
traff_model.add(Dense(1))

traff_model.compile(optimizer='adam', loss='mean_squared_error')
traff_model.fit(x_train, y_train, epochs=10, verbose=1)     
traff_model.evaluate(x_train, y_train)
# Out:
# /Users/MattPettit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   from ipykernel import kernelapp as app
# /Users/MattPettit/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Epoch 1/10
# 33742/33742 [==============================] - 2s 48us/step - loss: 5076225.6565
# Epoch 2/10
# 33742/33742 [==============================] - 1s 33us/step - loss: 3855069.5998
# Epoch 3/10
# 33742/33742 [==============================] - 1s 33us/step - loss: 3831153.5309
# Epoch 4/10
# 33742/33742 [==============================] - 1s 33us/step - loss: 3823679.1500
# Epoch 5/10
# 33742/33742 [==============================] - 1s 32us/step - loss: 3815633.4468
# Epoch 6/10
# 33742/33742 [==============================] - 1s 32us/step - loss: 3805887.1120
# Epoch 7/10
# 33742/33742 [==============================] - 1s 33us/step - loss: 3802960.0913
# Epoch 8/10
# 33742/33742 [==============================] - 1s 36us/step - loss: 3793331.6434
# Epoch 9/10
# 33742/33742 [==============================] - 1s 34us/step - loss: 3784372.4631
# Epoch 10/10
# 33742/33742 [==============================] - 1s 33us/step - loss: 3777935.2715
# 33742/33742 [==============================] - 1s 17us/step
# 3778692.8774672514

# %%
from sklearn.metrics import mean_squared_error

traff_pred = traff_model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, traff_pred))
rmse
# Out:
# 1946.5810798216935

# %%
np.mean(y)
# Out:
# 3259.8183553232097

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
pred=reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, pred))
np.mean(y)
# Out:
# 3267.5414880376156

# %%
# Out:
# /Users/MattPettit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# array([[        nan,         nan,         nan,         nan,  0.04074285],
#        [        nan, -3.57377687,         nan,         nan,         nan],
#        [        nan,         nan,         nan,         nan,         nan],
#        ...,
#        [        nan,  0.32628839,         nan,         nan,         nan],
#        [        nan,         nan,         nan,         n
# 48191        0  283.03     0.00      0.0          90  9/30/18 13:00
# 48192        0  283.48     0.00      0.0          90  9/30/18 14:00
# 48193        0  283.48     0.00      0.0          90  9/30/18 14:00
# 48194        0  283.84     0.00      0.0          75  9/30/18 15:00
# 48195        0  283.84     0.00      0.0          75  9/30/18 15:00
# 48196        0  284.38     0.00      0.0          75  9/30/18 16:00
# 48197        0  284.79     0.00      0.0          75  9/30/18 17:00
# 48198        0  284.20     0.25      0.0          75  9/30/18 18:00
# 48199        0  283.45     0.00      0.0          75  9/30/18 19:00
# 48200        0  282.76     0.00      0.0          90  9/30/18 20:00
# 48201        0  282.73     0.00      0.0          90  9/30/18 21:00
# 48202        0  282.09     0.00      0.0          90  9/30/18 22:00
# 48203        0  282.12     0.00      0.0          90  9/30/18 23:00
#
#        traffic_volume
# 0                5545
# 1                4516
# 2                4767
# 3                5026
# 4                4918
# 5                5181
# 6                5584
# 7                6015
# 8                5791
# 9                4770
# 10               3539
# 11               2784
# 12               2361
# 13               1529
# 14                963
# 15                506
# 16                321
# 17                273
# 18                367
# 19                814
# 20               2718
# 21               5673
# 22               6511
# 23               5471
# 24               5097
# 25               4887
# 26               5337
# 27               5692
# 28               6137
# 29               4623
# ...               ...
# 48174            3338
# 48175            2950
# 48176            2607
# 48177            3856
# 48178            1826
# 48179             920
# 48180             696
# 48181             364
# 48182             335
# 48183             444
# 48184             802
# 48185            1175
# 48186            2002
# 48187            2882
# 48188            3701
# 48189            4049
# 48190            4429
# 48191            4547
# 48192            4380
# 48193            4380
# 48194            4302
# 48195            4302
# 48196            4283
# 48197            4132
# 48198            3947
# 48199            3543
# 48200            2781
# 48201            2159
# 48202            1450
# 48203             954
#
# [48204 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-af31bf74060b> in <module>
#       6 lr_test = [.00001, .01, 1]
#       7 for lr in lr_test:
# ----> 8     model1 = get_new_model()
#       9     my_optimizer = SGD(lr=lr)
#      10     model.compile(optimizer=my_optimizer, loss='mean_squared_error')
#
# <ipython-input-75-af31bf74060b> in get_new_model(input_shape)
#       1 def get_new_model(input_shape=n_cols):
#       2     model1 = Sequential()
# ----> 3     model1.add(Dense(100, activation='relu', input_shape=input_shape))
#       4     model1.add(Dense(100, activation='relu'))
#       5     model1.add(Dense(1))
#
# ~/anaconda3/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     842         if 'input_shape' not in kwargs and 'input_dim' in kwargs:
#     843             kwargs['input_shape'] = (kwargs.pop('input_dim'),)
# --> 844         super(Dense, self).__init__(**kwargs)
#     845         self.units = units
#     846         self.activation = activations.get(activation)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/base_layer.py in __init__(self, **kwargs)
#     145                     batch_size = None
#     146                 batch_input_shape = (
# --> 147                     batch_size,) + tuple(kwargs['input_shape'])
#     148             self.batch_input_shape = batch_input_shape
#     149
#
# TypeError: 'int' object is not iterable
